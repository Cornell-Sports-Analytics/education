# %%
# Intro to Python for Sports Analytics

Welcome! This notebook is a hands-on introduction to the core Python libraries we'll use throughout new member education: **NumPy**, **Pandas**, **Matplotlib**, and **scikit-learn**.

By the end of this notebook, you should be able to:
- Load and explore a dataset with Pandas
- Perform basic numerical operations with NumPy
- Create simple visualizations with Matplotlib
- Fit a basic model with scikit-learn

**Before you start:** make sure you've uploaded the sample CSV file from the `data` folder to this Colab session (see the "Getting started" instructions in the README).

# %% [markdown]
# ## 1. Importing libraries
#
# We'll start by importing the libraries we need. It's common practice to import them with these standard aliases.

# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
